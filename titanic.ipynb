# %% [markdown]
# Random Forest

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
titanic_data = pd.read_csv('titanic_random-forest.csv')
titanic_data.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %%
titanic_data.shape
# Out:
# (418, 2)

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.325359
# std     120.810458    0.469070
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
x = titanic_data[['PassengerId']]
y = titanic_data['Survived']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
rf_classifier = RandomForestClassifier(n_estimators=100,random_state=42)
rf_classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_classifier.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
classification_report = classification_report(y_test, y_pred)

# %%
print(f'Accuracy: {accuracy}')
print('Classification Report:')
print(classification_report)
# Out:
# Accuracy: 0.5714285714285714
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.66      0.68        58
#            1       0.33      0.38      0.36        26
#
#     accuracy                           0.57        84
#    macro avg       0.52      0.52      0.52        84
# weighted avg       0.59      0.57      0.58        84

# %%
sample = x_test.iloc[0:1]
prediction = rf_classifier.predict(sample)

# %%
sample__dict = sample.iloc[0].to_dict()
print(f"\nSample Data: {sample__dict}")
print(f"\nPrediction: {'Survived' if prediction[0]==1 else 'Not Survived'}")
# Out:
# Sample Data: {'PassengerId': 1213}
#
# Prediction: Not Survived
